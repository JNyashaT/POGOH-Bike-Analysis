# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# POGOH Open Data provides datasets of user data per month. User data from 2023 was analyzed for this project.

# %%
january = pd.read_excel("january-2023.xlsx")
february = pd.read_excel("february-2023.xlsx")
march = pd.read_excel("march-2023.xlsx")
april = pd.read_excel("apr-2023.xlsx")
may = pd.read_excel("may-2023.xlsx")
june = pd.read_excel("june-2023.xlsx")
july = pd.read_excel("july-2023.xlsx")
august = pd.read_excel("august-2023.xlsx")
september = pd.read_excel("september-2023.xlsx")
october = pd.read_excel("october-2023.xlsx")
november = pd.read_excel("november-2023.xlsx")
december = pd.read_excel("december-2023.xlsx")

# %%
january
# Out:
#      Closed Status  Duration  Start Station Id          Start Date  \
# 0           NORMAL       288                29 2023-01-31 23:49:31
# 1           NORMAL       322                29 2023-01-31 23:43:11
# 2           NORMAL       483                 7 2023-01-31 22:43:12
# 3           NORMAL       236                29 2023-01-31 22:14:57
# 4           NORMAL       550                12 2023-01-31 22:10:09
# ...            ...       ...               ...                 ...
# 3824        NORMAL      1790                21 2023-01-01 00:39:18
# 3825        NORMAL      1471                19 2023-01-01 00:23:14
# 3826        NORMAL      5768                 6 2023-01-01 00:21:41
# 3827  GRACE_PERIOD        27                 6 2023-01-01 00:20:31
# 3828        NORMAL       896                30 2023-01-01 00:11:55
#
#                   Start Station Name            End Date  End Station Id  \
# 0           Forbes Ave & Schenley Dr 2023-01-31 23:54:19            20.0
# 1           Forbes Ave & Schenley Dr 2023-01-31 23:48:33            10.0
# 2             Liberty Ave & Gross St 2023-01-31 22:51:15            12.0
# 3           Forbes Ave & Schenley Dr 2023-01-31 22:18:53            10.0
# 4     O'Hara St and University Place 2023-01-31 22:19:19            15.0
# ...                              ...                 ...             ...
# 3824        Liberty Ave & Stanwix St 2023-01-01 01:09:08            24.0
# 3825             42nd St & Butler St 2023-01-01 00:47:45            15.0
# 3826              10th St & Penn Ave 2023-01-01 01:57:49             4.0
# 3827              10th St & Penn Ave 2023-01-01 00:20:58             6.0
# 3828       Shady Ave & Ellsworth Ave 2023-01-01 00:26:51            26.0
#
#                               End Station Name Rider Type
# 0       Boulevard of the Allies & Parkview Ave     MEMBER
# 1                      Zulema St & Coltart Ave     MEMBER
# 2               O'Hara St and University Place     MEMBER
# 3                      Zulema St & Coltart Ave     MEMBER
# 4                           Ivy St & Walnut St     MEMBER
# ...                                        ...        ...
# 3824                        Penn Ave & 33rd St     MEMBER
# 3825                        Ivy St & Walnut St     CASUAL
# 3826         Burns White Center at 3 Crossings     MEMBER
# 3827                        10th St & Penn Ave     MEMBER
# 3828  S 27th St & Sidney St. (Southside Works)     MEMBER
#
# [3829 rows x 9 columns]

# %% [markdown]
# Since there are separate files for each month, I will combine them to get a cumulative dataset for the entire year.

# %%
months = [january, february, march, april, may, june, july, august, september, october, november, december]

# %%
combined = pd.concat(months)

# %%
combined
# Out:
#       Closed Status  Duration  Start Station Id           Start Date  \
# 0            NORMAL       288                29  2023-01-31 23:49:31
# 1            NORMAL       322                29  2023-01-31 23:43:11
# 2            NORMAL       483                 7  2023-01-31 22:43:12
# 3            NORMAL       236                29  2023-01-31 22:14:57
# 4            NORMAL       550                12  2023-01-31 22:10:09
# ...             ...       ...               ...                  ...
# 16136        NORMAL       605                51  2023-12-01 00:05:07
# 16137        NORMAL      1271                50  2023-12-01 00:04:56
# 16138        NORMAL      1302                50  2023-12-01 00:04:24
# 16139        NORMAL       317                48  2023-12-01 00:01:21
# 16140        NORMAL      2464                58  2023-12-01 00:00:49
#
#                    Start Station Name             End Date  End Station Id  \
# 0            Forbes Ave & Schenley Dr  2023-01-31 23:54:19            20.0
# 1            Forbes Ave & Schenley Dr  2023-01-31 23:48:33            10.0
# 2              Liberty Ave & Gross St  2023-01-31 22:51:15            12.0
# 3            Forbes Ave & Schenley Dr  2023-01-31 22:18:53            10.0
# 4      O'Hara St and University Place  2023-01-31 22:19:19            15.0
# ...                               ...                  ...             ...
# 16136        Coltart Ave & Forbes Ave  2023-12-01 00:15:12            51.0
# 16137            Atwood St & Bates St  2023-12-01 00:26:07            13.0
# 16138            Atwood St & Bates St  2023-12-01 00:26:06            13.0
# 16139     S Millvale Ave & Centre Ave  2023-12-01 00:06:38            13.0
# 16140        W North Ave & Federal St  2023-12-01 00:41:53            31.0
#
#                              End Station Name Rider Type
# 0      Boulevard of the Allies & Parkview Ave     MEMBER
# 1                     Zulema St & Coltart Ave     MEMBER
# 2              O'Hara St and University Place     MEMBER
# 3                     Zulema St & Coltart Ave     MEMBER
# 4                          Ivy St & Walnut St     MEMBER
# ...                                       ...        ...
# 16136                Coltart Ave & Forbes Ave     MEMBER
# 16137              S Bouquet Ave & Sennott St     MEMBER
# 16138              S Bouquet Ave & Sennott St     MEMBER
# 16139              S Bouquet Ave & Sennott St     MEMBER
# 16140                        First Ave & B St     MEMBER
#
# [211246 rows x 9 columns]

# %%
combined.dtypes
# Out:
# Closed Status          object
# Duration                int64
# Start Station Id        int64
# Start Date             object
# Start Station Name     object
# End Date               object
# End Station Id        float64
# End Station Name       object
# Rider Type             object
# dtype: object

# %%
combined.describe()
# Out:
#            Duration  Start Station Id  End Station Id
# count  2.112460e+05     211246.000000   211106.000000
# mean   1.167303e+03         25.332697       25.058014
# std    8.246505e+03         13.918654       13.928231
# min    0.000000e+00          1.000000        1.000000
# 25%    2.520000e+02         13.000000       13.000000
# 50%    4.470000e+02         23.000000       23.000000
# 75%    9.800000e+02         34.000000       34.000000
# max    1.969581e+06         62.000000       62.000000

# %% [markdown]
# To organize the values, I will add another column to add months to each row. The start and end date columns contain both the date and the timestamp, so adding months will make the data a lot clearer.

# %%
combined["Start Date"] = pd.to_datetime(combined["Start Date"])
combined["End Date"] = pd.to_datetime(combined["End Date"])

# %%
def get_month(date):
    if date.month == 1:
        return "January"
    elif date.month == 2:
        return "February"
    elif date.month == 3:
        return "March"
    elif date.month == 4:
        return "April"
    elif date.month == 5:
        return "May"
    elif date.month == 6:
        return "June"
    elif date.month == 7:
        return "July"
    elif date.month == 8:
        return "August"
    elif date.month == 9:
        return "September"
    elif date.month == 10:
        return "October"
    elif date.month == 11:
        return "November"
    elif date.month == 12:
        return "December"

# %% [markdown]
# This function will return the month of each value depending on what the month value in the datetime format corresponds to.

# %%
combined["Month"] = combined["Start Date"].apply(get_month)

# %%
combined
# Out:
#       Closed Status  Duration  Start Station Id          Start Date  \
# 0            NORMAL       288                29 2023-01-31 23:49:31
# 1            NORMAL       322                29 2023-01-31 23:43:11
# 2            NORMAL       483                 7 2023-01-31 22:43:12
# 3            NORMAL       236                29 2023-01-31 22:14:57
# 4            NORMAL       550                12 2023-01-31 22:10:09
# ...             ...       ...               ...                 ...
# 16136        NORMAL       605                51 2023-12-01 00:05:07
# 16137        NORMAL      1271                50 2023-12-01 00:04:56
# 16138        NORMAL      1302                50 2023-12-01 00:04:24
# 16139        NORMAL       317                48 2023-12-01 00:01:21
# 16140        NORMAL      2464                58 2023-12-01 00:00:49
#
#                    Start Station Name            End Date  End Station Id  \
# 0            Forbes Ave & Schenley Dr 2023-01-31 23:54:19            20.0
# 1            Forbes Ave & Schenley Dr 2023-01-31 23:48:33            10.0
# 2              Liberty Ave & Gross St 2023-01-31 22:51:15            12.0
# 3            Forbes Ave & Schenley Dr 2023-01-31 22:18:53            10.0
# 4      O'Hara St and University Place 2023-01-31 22:19:19            15.0
# ...                               ...                 ...             ...
# 16136        Coltart Ave & Forbes Ave 2023-12-01 00:15:12            51.0
# 16137            Atwood St & Bates St 2023-12-01 00:26:07            13.0
# 16138            Atwood St & Bates St 2023-12-01 00:26:06            13.0
# 16139     S Millvale Ave & Centre Ave 2023-12-01 00:06:38            13.0
# 16140        W North Ave & Federal St 2023-12-01 00:41:53            31.0
#
#                              End Station Name Rider Type     Month
# 0      Boulevard of the Allies & Parkview Ave     MEMBER   January
# 1                     Zulema St & Coltart Ave     MEMBER   January
# 2              O'Hara St and University Place     MEMBER   January
# 3                     Zulema St & Coltart Ave     MEMBER   January
# 4                          Ivy St & Walnut St     MEMBER   January
# ...                                       ...        ...       ...
# 16136                Coltart Ave & Forbes Ave     MEMBER  December
# 16137              S Bouquet Ave & Sennott St     MEMBER  December
# 16138              S Bouquet Ave & Sennott St     MEMBER  December
# 16139              S Bouquet Ave & Sennott St     MEMBER  December
# 16140                        First Ave & B St     MEMBER  December
#
# [211246 rows x 10 columns]

# %%
combined.dtypes
# Out:
# Closed Status                 object
# Duration                       int64
# Start Station Id               int64
# Start Date            datetime64[ns]
# Start Station Name            object
# End Date              datetime64[ns]
# End Station Id               float64
# End Station Name              object
# Rider Type                    object
# Month                         object
# dtype: object

# %%
combined.isna().sum()
# Out:
# Closed Status           0
# Duration                0
# Start Station Id        0
# Start Date              0
# Start Station Name      0
# End Date                0
# End Station Id        140
# End Station Name      135
# Rider Type              0
# Month                   0
# dtype: int64

# %% [markdown]
# For the most part, POGOH has data on where riders may start, but not necessarily where they finish. This could account for people who may not indicate this in the bikeshare app. I am going to remove the missing values from this column, because it is a relatively small number compared to the total rides.

# %%
combined = combined[combined["End Station Id"].notna()]
combined = combined[combined["End Station Name"].notna()]

# %%
combined.isna().sum()
# Out:
# Closed Status         0
# Duration              0
# Start Station Id      0
# Start Date            0
# Start Station Name    0
# End Date              0
# End Station Id        0
# End Station Name      0
# Rider Type            0
# Month                 0
# dtype: int64

# %%
month_order = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

import seaborn as sns

sns.countplot(x="Month", data=combined, order = month_order)
plt.xticks(rotation = 90)
plt.ylabel("Number of Rides")
plt.xlabel("Month")
plt.title("Number of POGOH Rides Per Month in 2023")
# Out:
# Text(0.5, 1.0, 'Number of POGOH Rides Per Month in 2023')

# %% [markdown]
# POGOH bikes are mostly utilized in August, September, October, and November. This timeframe typically marks the beginning of fall semester for the universities in the Pittsburgh area.

# %%
sns.barplot(combined, x="Month", y="Duration", order = month_order)
plt.xticks(rotation = 90)
plt.ylabel("Total Duration (in minutes)")
plt.xlabel("Month")
plt.title("Total Duration of POGOH Rides Per Month in 2023")
# Out:
# Text(0.5, 1.0, 'Total Duration of POGOH Rides Per Month in 2023')

# %% [markdown]
# People tend to go on longer rides during the summer months.

# %%
combined.groupby(["Start Station Id"]).agg({"Rider Type":"count"}).sort_values("Rider Type", ascending=False)
# Out:
#                   Rider Type
# Start Station Id
# 13                     19131
# 20                     14923
# 29                     12213
# 34                     12133
# 12                     11169
# ...                      ...
# 42                       110
# 43                        83
# 45                        80
# 60                        74
# 62                         4
#
# [61 rows x 1 columns]

# %%
combined.groupby(["End Station Id"]).agg({"Rider Type":"count"}).sort_values("Rider Type", ascending=False)
# Out:
#                 Rider Type
# End Station Id
# 13.0                 19744
# 20.0                 14435
# 29.0                 13148
# 12.0                 11691
# 34.0                 10614
# ...                    ...
# 46.0                   125
# 56.0                   118
# 45.0                    89
# 43.0                    79
# 62.0                     4
#
# [61 rows x 1 columns]

# %%
sns.histplot(data = combined, x="Start Station Id", color = "#0c2d48", bins = 25)
plt.xlabel("Starting Station ID")
plt.title("Distribution of Starting Locations")
# Out:
# Text(0.5, 1.0, 'Distribution of Starting Locations')

# %%
sns.histplot(data = combined, x="End Station Id", color = "#0c2d48", bins = 25)
plt.xlabel("End Station ID")
plt.title("Distribution of Ending Locations")
# Out:
# Text(0.5, 1.0, 'Distribution of Ending Locations')
